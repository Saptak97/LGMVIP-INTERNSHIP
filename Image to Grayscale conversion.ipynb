# %% [markdown]
# #  LGMVIP INTERNSHIP(DATA SCIENCE)

# %% [markdown]
# #  TASK 4 = IMAGE TO PENCIL SKETCH WITH PYTHON

# %% [markdown]
# #  SAPTAK BANERJEE

# %%
import numpy as np
import cv2

import matplotlib.pyplot as plt

# %%
def show_image(img):
  cv2.imshow("MSD", img)
  cv2.waitKey(0)
  cv2.destroyAllWindows()

# %%
# LOADING IMAGE
img = cv2.imread(r'Dhoni.jpg')
show_image(img)

# %%
# DISPLAYING IMAGE
plt.figure(num = 1, figsize = (8, 8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image', fontsize = 26)
plt.gca().axes.get_yaxis().set_visible(False)
plt.gca().axes.get_xaxis().set_visible(False)
plt.show()

# %%
def dodgeV2(image, mask):
     return cv2.divide(image, 255 - mask, scale = 256)

# %%
def blend(front, back):
    result =  front*255/(255 - back)
    result[result > 255] = 255
    result[back == 255] = 255
    return result

# %%
def render(img_rgb):
    img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
    
#     APPLYING GAUSSIAN BLUR TO THE GRAYSCALE IMAGE
 
    img_blur = cv2.GaussianBlur(img_gray, (21, 21), 0, 0)
        
#         INVERTING THE BLUR IMAGE

    inverted_img = 255 - img_blur
    
    
#        APPLYING THE DODGEV2 FUNCTION

    img_blend = dodgeV2(img_gray, inverted_img)
    
#     BLENDING THE IMAGE

    img_final = 1 - blend(img_blend, img_gray)
    
    
    return img_final

# %%
final_image = render(img)
show_image(final_image)
# Out:
# <ipython-input-19-6a03906924b6>:2: RuntimeWarning: divide by zero encountered in true_divide
#   result =  front*255/(255 - back)
